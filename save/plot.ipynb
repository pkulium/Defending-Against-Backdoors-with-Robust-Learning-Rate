# %%
import matplotlib.pyplot as plt

iterations = list(range(1, 5))  # Assume there are 4 iterations for demonstration

data = {
    -1.0: {'CleanACC': [0.9284, 0.9262, 0.9262, 0.9176]},
    0.0: {'CleanACC': [0.9124, 0.9142, 0.9155, 0.9111]},
    1.0: {'CleanACC': [0.9250, 0.9277, 0.9298, 0.9263]},
    2.0: {'CleanACC': [0.9300, 0.9321, 0.9345, 0.9302]},
    3.0: {'CleanACC': [0.9143, 0.9178, 0.9167, 0.9156]},
    4.0: {'CleanACC': [0.9200, 0.9222, 0.9233, 0.9211]},
    5.0: {'CleanACC': [0.9355, 0.9376, 0.9387, 0.9362]},
    6.0: {'CleanACC': [0.9166, 0.9188, 0.9209, 0.9180]},
    7.0: {'CleanACC': [0.9288, 0.9310, 0.9333, 0.9299]},
    8.0: {'CleanACC': [0.9156, 0.9177, 0.9166, 0.9150]},
    9.0: {'CleanACC': [0.9233, 0.9254, 0.9278, 0.9244]}
}


# Plotting data
for label, values in data.items():
    plt.plot(iterations, values['CleanACC'], label=f'Clean label {label}', marker='o')

plt.title("CleanACC across iterations")
plt.xlabel("Iteration")
plt.ylabel("CleanACC")
plt.grid(True)

# Adjust the legend to be outside and to the right of the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.tight_layout()  # Adjusts the plot so that everything fits
plt.show()

# %%
import matplotlib.pyplot as plt

iterations = [500, 1000, 1500, 2000]

# Extracting the PoisonACC values for different clean_labels
poison_acc_values = {
    -1.0: [0.2421, 0.2122, 0.0433, 0.0854],
    0.0: [0.9998, 0.7934, 0.9989, 0.9878],
    1.0: [0.7448, 0.7061, 0.4286, 0.2217],
    2.0: [0.8989, 0.4497, 0.1283, 0.0897],
    3.0: [0.1898, 0.0829, 0.0233, 0.0096],
    4.0: [0.7404, 0.1914, 0.0898, 0.0243],
    5.0: [0.5624, 0.0754, 0.0272, 0.0089],
    6.0: [0.8668,0.2099,0.0744,0.0437],  
    7.0: [0.9229,0.4432,0.0536,0.1232],  
    8.0: [0.9362 ,0.8789 ,0.3237 ,0.3779 ],  
    9.0: [0.8840,0.6007,0.6003,0.1883],  
}

# Plotting the PoisonACC
for clean_label, acc_values in poison_acc_values.items():
    plt.plot(iterations[:len(acc_values)], acc_values, label=f"Clean Label = {clean_label}")

plt.xlabel('Iterations')
plt.ylabel('PoisonACC')
plt.title('PoisonACC across Iterations for Different Clean Labels')



plt.title("CleanACC across iterations")
plt.xlabel("Iteration")
plt.ylabel("CleanACC")
plt.grid(True)

# Adjust the legend to be outside and to the right of the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.tight_layout()  # Adjusts the plot so that everything fits
plt.show()

# %%
import matplotlib.pyplot as plt

iterations_clean = [500, 1000, 1500, 2000]

data = {
    -1.0: {'CleanACC': [0.9284, 0.9262, 0.9262, 0.9176]},
    0.0: {'CleanACC': [0.9124, 0.9142, 0.9155, 0.9111]},
    1.0: {'CleanACC': [0.9250, 0.9277, 0.9298, 0.9263]},
    2.0: {'CleanACC': [0.9300, 0.9321, 0.9345, 0.9302]},
    3.0: {'CleanACC': [0.9143, 0.9178, 0.9167, 0.9156]},
    4.0: {'CleanACC': [0.9200, 0.9222, 0.9233, 0.9211]},
    5.0: {'CleanACC': [0.9355, 0.9376, 0.9387, 0.9362]},
    6.0: {'CleanACC': [0.9166, 0.9188, 0.9209, 0.9180]},
    7.0: {'CleanACC': [0.9288, 0.9310, 0.9333, 0.9299]},
    8.0: {'CleanACC': [0.9156, 0.9177, 0.9166, 0.9150]},
    9.0: {'CleanACC': [0.9233, 0.9254, 0.9278, 0.9244]}
}
iterations_poison = [500, 1000, 1500, 2000]
poison_acc_values = {
    -1.0: [0.2421, 0.2122, 0.0433, 0.0854],
    0.0: [0.9998, 0.7934, 0.9989, 0.9878],
    1.0: [0.7448, 0.7061, 0.4286, 0.2217],
    2.0: [0.8989, 0.4497, 0.1283, 0.0897],
    3.0: [0.1898, 0.0829, 0.0233, 0.0096],
    4.0: [0.7404, 0.1914, 0.0898, 0.0243],
    5.0: [0.5624, 0.0754, 0.0272, 0.0089],
    6.0: [0.8668,0.2099,0.0744,0.0437],  
    7.0: [0.9229,0.4432,0.0536,0.1232],  
    8.0: [0.9362 ,0.8789 ,0.3237 ,0.3779 ],  
    9.0: [0.8840,0.6007,0.6003,0.1883],  
}
# Create a figure with two subplots (side by side)
fig, axs = plt.subplots(1, 2, figsize=(15, 6))

# Let's rock the CleanACC plot on the left subplot
for label, values in data.items():
    axs[0].plot(iterations_clean, values['CleanACC'], label=f'Clean Label {label}', marker='o')
axs[0].set_title("CleanACC across iterations")
axs[0].set_xlabel("Iteration")
axs[0].set_ylabel("CleanACC")
axs[0].grid(True)
axs[0].legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# And then drop the beats with the PoisonACC on the right subplot
for clean_label, acc_values in poison_acc_values.items():
    axs[1].plot(iterations_poison[:len(acc_values)], acc_values, label=f"Clean Label = {clean_label}")
axs[1].set_title("PoisonACC across iterations")
axs[1].set_xlabel("Iteration")
axs[1].set_ylabel("PoisonACC")
axs[1].grid(True)
# axs[1].legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# Make sure everything's cozy and looking good
plt.tight_layout()
plt.savefig("anp_partial.png", bbox_inches="tight", dpi=300)
plt.show()
